# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

keywords = ['python', 'алгоритм']
# получаем страницу с самыми свежими постами
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')
# добираемся до постов
articles = soup.find_all('article', class_= 'post post_preview')
# получаем ссылки
links = list(map(lambda x: x.find('a', class_= 'post__title_link').get('href'), articles))
# получаем текст preview
post_body = list(map(lambda x: x.find('div', class_= 'post__body post__body_crop').text.strip(), articles))

# %%
hub_pre = pd.DataFrame()
# итерация по ссылкам и preview
for link, post in zip(links, post_body):
    # проверка условия вхождения слов в preview
    if any([keyword in post.lower() for keyword in keywords]):
        # Дата публикации находится на полной странице. Для этого получаем страницу целиком.
        req_full = requests.get(link) 
        soup_full = BeautifulSoup(req_full.text, 'html.parser')
#         Вытаскиваем дату
        date = pd.to_datetime(soup_full.find('span', class_ = 'post__time').get('data-time_published')).date()
#     Получаем название
        title = soup_full.find('span', class_ = 'post__title-text').text
        row = {'Дата':date, 'Заголовок':title, 'Ссылка': link, }
        hub_pre = pd.concat([hub_pre, pd.DataFrame([row])])
hub_pre
# Out:
#          Дата                Заголовок                            Ссылка
# 0  2020-12-15  Radix sort — выжать всё  https://habr.com/ru/post/533206/

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
hub_full = pd.DataFrame()
for link in links:
    req_full = requests.get(link)
    soup_full = BeautifulSoup(req_full.text, 'html.parser')
    post = soup_full.find('div', class_= 'post__body post__body_full').text.strip()
    if any([keyword in post.lower() for keyword in keywords]): 
        date = pd.to_datetime(soup_full.find('span', class_ = 'post__time').get('data-time_published')).date()
        title = soup_full.find('span', class_ = 'post__title-text').text
        row = {'Дата':date, 'Заголовок':title, 'Ссылка': link, 'Текст_статьи': post}
        hub_full = pd.concat([hub_full, pd.DataFrame([row])])               
          
hub_full
# Out:
#          Дата                                          Заголовок  \
# 0  2020-12-15                            Radix sort — выжать всё
# 0  2020-12-15  Ковыряемся внутри умной тепловой камеры с микр...
# 0  2020-12-15                      Как написать (игрушечную) JVM
# 0  2020-12-15      Как далеки мы от беспроводного электричества?
# 0  2020-12-15           Бенчмарки Apple M1 в реальной разработке
# 0  2020-12-15  Построение инфраструктуры распределенной трасс...
# 0  2020-12-15  Head-of-Line Blocking в QUIC и HTTP/3: Подробн...
#
#                                               Ссылка  \
# 0                   https://habr.com/ru/post/533206/
# 0    https://habr.com/ru/company/itelma/blog/533250/
# 0   https://habr.com/ru/company/timeweb/blog/533244/
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 0                   https://habr.com/ru/post/533232/
# 0      https://habr.com/ru/company/otus/blog/533234/
# 0  https://habr.com/ru/company/selectel/blog/532868/
#
#                                         Текст_статьи
# 0  Приветствую всех любителей алгоритмов. Хочу Ва...
# 0  Китайская компания Hikvision — один из ведущих...
# 0  Статья про KVM оказалась интересной для читате...
# 0  Привет Хабр! Я хочу рассказать тебе историю о ...
# 0  Я очень впечатлён результатами тестов Apple M1...
# 0  Для будущих учащихся на курсе "Highload Archit...
# 0  Как вы могли слышать, после четырех лет разраб...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import requests
import pandas as pd
import time
import json

EMAIL = ['xxx@ya.ru', 'yyy@y.com']
URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

res = pd.DataFrame({})
for email in EMAIL:
    data = {'emailAddresses': [email]}
    time.sleep(0.5)
    req = requests.post(URL, json = data, headers = {'Vaar-Version': '0', 'Vaar-Header-App-Product': 'hackcheck-web-avast'})
    df = pd.DataFrame(req.json()['breaches']).transpose()
    df['email'] = email  
    res = pd.concat([df, res])
res2 = res.loc[:,['email', 'publishDate', 'site', 'description']]
res2.columns = ['почта', 'дата утечки', 'источник утечки', 'описание утечки']
res2
# Out:
#            почта           дата утечки      источник утечки  \
# 17110  yyy@y.com  2020-01-03T00:00:00Z        azcentral.com
# 17670  yyy@y.com  2020-05-28T00:00:00Z          wishbone.io
# 13094  yyy@y.com  2017-11-04T00:00:00Z       myheritage.com
# 16768  yyy@y.com  2019-06-13T00:00:00Z            canva.com
# 41     yyy@y.com  2016-10-24T00:00:00Z          dropbox.com
# 2      yyy@y.com  2016-10-21T00:00:00Z         linkedin.com
# 3587   yyy@y.com  2017-03-01T00:00:00Z         rayli.com.cn
# 17009  yyy@y.com  2019-10-17T00:00:00Z            zynga.com
# 3      yyy@y.com  2016-10-21T00:00:00Z            adobe.com
# 13662  yyy@y.com  2018-02-18T00:00:00Z           netlog.com
# 3520   yyy@y.com  2017-03-15T00:00:00Z       globalreach.eu
# 15     yyy@y.com  2016-10-23T00:00:00Z            imesh.com
# 3669   yyy@y.com  2017-03-24T00:00:00Z            youku.com
# 88     xxx@ya.ru  2016-11-07T00:00:00Z       ir.netease.com
# 17847  xxx@ya.ru  2020-07-30T00:00:00Z             hurb.com
# 16613  xxx@ya.ru  2019-03-28T00:00:00Z     verifications.io
# 17609  xxx@ya.ru  2020-05-21T00:00:00Z               vk.com
# 60     xxx@ya.ru  2016-11-01T00:00:00Z               qip.ru
# 17093  xxx@ya.ru  2019-12-05T00:00:00Z      wowprogress.com
# 13094  xxx@ya.ru  2017-11-04T00:00:00Z       myheritage.com
# 17346  xxx@ya.ru  2020-02-06T00:00:00Z  flyffpenya-shop.com
# 17345  xxx@ya.ru  2020-02-06T00:00:00Z   cityofvillains.com
# 41     xxx@ya.ru  2016-10-24T00:00:00Z          dropbox.com
# 12     xxx@ya.ru  2016-10-29T00:00:00Z               vk.com
# 18150  xxx@ya.ru  2020-11-19T00:00:00Z          gonitro.com
# 3560   xxx@ya.ru  2017-03-15T00:00:00Z           wanadoo.fr
#
#                                          описание утечки
# 17110  At an unconfirmed date, online Arizona newspap...
# 17670  In January 2020, the online poll website Wishb...
# 13094  In October 2017, a customer database belonging...
# 16768  In May 2019, graphic-design site Canva's datab...
# 41     Cloud storage company Dropbox suffered a major...
# 2      In 2012, online professional networking platfo...
# 3587   On an unconfirmed date, Chinese gossip site Ra...
# 17009  In September 2019, the game developer Zynga wa...
# 3      In October of 2013, criminals penetrated Adobe...
# 13662  Netlog (formerly known as Facebox and Bingbox)...
# 3520   In 2016, Global Reach Technology's database wa...
# 15     In June 2016, a cache of over 51 million user ...
# 3669   Youku is a large Chinese video content company...
# 88     In October 2015, the Chinese internet and gami...
# 17847  In March 2019, the Brazilian travel agency Her...
# 16613  Big data e-mail verification platform verifica...
# 17609  At some time in 2020, the Russian social netwo...
# 60     In 2011, Russian instant messaging service pro...
# 17093  At an unconfirmed date, the World of Warcraft ...
# 13094  In October 2017, a customer database belonging...
# 17346  In 2015, online gaming shop Flyffpenya Shop wa...
# 17345  In January 2015, the online role-playing game ...
# 41     Cloud storage company Dropbox suffered a major...
# 12     Popular Russian social networking platform VKo...
# 18150  In October 2020, the PDF editor Nitro was alle...
# 3560   At an unconfirmed date Orange (Wanadoo)'s user...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json

NEWSFEED_REQUEST = 'https://api.vk.com/method/wall.get?'
TOKEN = '0'
VERSION = '5.103'
SLEEP = 0.33
GROUP = 'netology'
params = {
    'access_token': TOKEN,
    'v': VERSION,
    'count': 50,
    'domain':GROUP,
}
res = requests.get(NEWSFEED_REQUEST, params)
df = pd.DataFrame(res.json()['response']['items'])[['date', 'text']]
df.date = pd.to_datetime(df.date, unit='s')
df
# Out:
#                   date                                               text
# 0  2020-12-07 10:05:00  Наш предновогодний digital-марафон продолжаетс...
# 1  2020-12-13 13:18:00  🎁 Запустили страницу с подарками и скидками от...
# 2  2020-12-13 08:19:00  Чужой пример заразителен 😉\nИстории успеха кру...
# 3  2020-12-12 12:56:00  В новой афише мероприятий конференции по марке...
# 4  2020-12-12 08:04:01  Как упростить работу с таблицами, улучшить диа...
# 5  2020-12-11 14:18:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 6  2020-12-11 07:28:00  Поиграем со шрифтами?😅 \n\nРазбираемся с графи...
# 7  2020-12-10 14:48:00  Учёт доходов и расходов — первый шаг к устране...
# 8  2020-12-10 11:18:00  *партнёрский пост*\n\nПодводим итоги года с Le...
# 9  2020-12-10 07:19:00  Будущее ближе, чем мы думаем 🤖 \n \nВ новом Da...
# 10 2020-12-09 13:25:03  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 11 2020-12-09 07:13:00  📹 15 декабря стартует бесплатный онлайн-марафо...
# 12 2020-12-08 14:38:00  Представим Сашу и Васю, которые работают в одн...
# 13 2020-12-08 07:42:00  Кто-то только начал заниматься копирайтингом, ...
# 14 2020-12-07 14:49:00  Новый год на носу — самое время подводить итог...
# 15 2020-12-07 07:19:00  📝 Записывайтесь на бесплатный курс «Диджитал-с...
# 16 2020-12-06 08:38:00  Когда дедлайн по проекту уже близко, то менедж...
# 17 2020-12-05 12:56:00  В сегодняшней афише мероприятий конференции о ...
# 18 2020-12-05 08:56:00  Подборка статей для тех, кто не знает, какой я...
# 19 2020-12-04 15:36:00  Еженедельный Giveaway, тысячи фолловеров из ра...
# 20 2020-12-04 07:46:00  Таргетолог, копирайтер, бренд-менеджер, сммщик...
# 21 2020-12-03 14:38:00  Поиск работы — волнительный процесс. \n \nПрои...
# 22 2020-12-03 07:46:00  Карьера сегодня — не прямой и понятный путь из...
# 23 2020-12-02 13:35:02  У нас сегодня Нето-викторина 🤩\n\nМы подготови...
# 24 2020-12-02 07:23:00  🔥 19 декабря пройдёт бесплатная онлайн-конфере...
# 25 2020-12-01 14:51:00  С тире или без? А может, дефис поставить?\n\nР...
# 26 2020-12-01 07:23:00  Что надо знать и уметь, чтобы работать с данны...
# 27 2020-11-30 13:53:00  📆 Составляем адвент-календарь взрослого челове...
# 28 2020-11-30 08:00:10  В воздухе уже витает дух Нового года, а мы уст...
# 29 2020-11-30 07:07:00  🔥 Запустили бесплатный курс «Как перенести сво...
# 30 2020-11-29 09:27:00  Неопределённость, непредсказуемые ситуации, ре...
# 31 2020-11-28 14:28:00  Онлайн-мероприятия декабря: конференции для ди...
# 32 2020-11-28 11:28:00  Онлайн-курсы становятся всё популярнее, рынок ...
# 33 2020-11-28 07:23:00  Собрали статьи, которые помогут сделать работу...
# 34 2020-11-27 14:14:00  Эффективность работы сммщика зависит не только...
# 35 2020-11-27 07:27:00  Что нужно знать для старта в Data Science, зач...
# 36 2020-11-26 14:31:00  Каждый день мы принимаем десятки решений. От н...
# 37 2020-11-26 08:27:00  Ставьте палец вверх и переходите по ссылке в о...
# 38 2020-11-25 13:05:12  Разыгрываем 10 доступов к библиотеке видеокурс...
# 39 2020-11-25 07:31:00  30 ноября стартует бесплатный курс «Основы HTM...
# 40 2020-11-24 14:43:00  Резюме без сопроводительного письма открывает ...
# 41 2020-11-24 07:22:00  Как выбрать тему для статьи, побороть страх чи...
# 42 2020-11-23 14:04:00  И мы не устояли перед магией Чёрной пятницы — ...
# 43 2020-11-23 07:18:00  🤖 Запустили бесплатный курс «Профессии в Data ...
# 44 2020-11-22 13:22:00  *партнёрский пост*\n\nНедавно на SEOnews.ru вы...
# 45 2020-11-22 08:28:00  Как себя чувствует человек, существующий в фор...
# 46 2020-11-21 12:22:00  *партнёрский пост* \n \nС 11 по 13 декабря сос...
# 47 2020-11-21 08:22:00  Вам точно стоит попробовать Python, если вы ни...
# 48 2020-11-20 14:36:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 49 2020-11-20 07:28:00  Разбираемся с основами HTML и CSS и выбираем н...
